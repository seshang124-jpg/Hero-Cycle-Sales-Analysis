# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="7539901997",
    database="hero"
)

# %%
import mysql.connector

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
connection

# %%
query = "SHOW TABLES"
tables = pd.read_sql(query, connection)
tables
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_17644\1272647565.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   tables = pd.read_sql(query, connection)
#       Tables_in_hero
# 0             brands
# 1         categories
# 2  customer_segments
# 3          customers
# 4        order_items
# 5             orders
# 6           products
# 7             staffs
# 8             stocks
# 9             stores

# %%
query = "SELECT * FROM orders"
orders = pd.read_sql(query, connection)
orders.head()
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_17644\653430989.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   orders = pd.read_sql(query, connection)
#    OrderId  CustomerId  OrderStatus   OrderDate RequiredDate ShippedDate  \
# 0        1         259  4-Completed  2016-01-01   2016-01-03  2016-01-03
# 1        2        1212  4-Completed  2016-01-01   2016-01-04  2016-01-03
# 2        3         523  4-Completed  2016-01-02   2016-01-05  2016-01-03
# 3        4         175  4-Completed  2016-01-03   2016-01-04  2016-01-05
# 4        5        1324  4-Completed  2016-01-03   2016-01-06  2016-01-06
#
#    StoreId  StaffId
# 0        1        2
# 1        2        6
# 2        2        7
# 3        1        3
# 4        2        6

# %%
query = "SELECT * FROM customers"
customers = pd.read_sql(query, connection)
customers.head()
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_17644\2333198432.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   customers = pd.read_sql(query, connection)
#    CustomerId             Name           Phone                    Email  \
# 0           1      Debra Burks       not_found    debra.burks@yahoo.com
# 1           2       Kasha Todd       not_found     kasha.todd@yahoo.com
# 2           3    Tameka Fisher       not_found    tameka.fisher@aol.com
# 3           4     Daryl Spence       not_found     daryl.spence@aol.com
# 4           5  Charolette Rice  (916) 381-6003  charolette.rice@msn.com
#
#                  Street           City State  ZipCode
# 0      9273 Thorne Ave.   Orchard Park    NY    14127
# 1       910 Vine Street       Campbell    CA    95008
# 2  769C Honey Creek St.  Redondo Beach    CA    90278
# ...

# %%
query ="select * from order_items"
order_items =pd.read_sql(query,connection)
order_items.head()
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_17644\1761167775.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   order_items =pd.read_sql(query,connection)
#    OrderId  ItemId  ProductId                                     ProductName  \
# 0        1       1         20  Electra Townie Original 7D EQ - Women's - 2016
# 1        1       2          8           Trek Remedy 29 Carbon Frameset - 2016
# 2        1       3         10                          Surly Straggler - 2016
# 3        1       4         16            Electra Townie Original 7D EQ - 2016
# 4        1       5          4                        Trek Fuel EX 8 29 - 2016
#
#    CategoryId         CategoryName  Quantity  ListPrice  Discount  TotalSales  \
# 0           3    Cruisers Bicycles         1     599.99      0.20    479.9920
# ...

# %%
customers
# Out:
#       CustomerId             Name           Phone                    Email  \
# 0              1      Debra Burks       not_found    debra.burks@yahoo.com
# 1              2       Kasha Todd       not_found     kasha.todd@yahoo.com
# 2              3    Tameka Fisher       not_found    tameka.fisher@aol.com
# 3              4     Daryl Spence       not_found     daryl.spence@aol.com
# 4              5  Charolette Rice  (916) 381-6003  charolette.rice@msn.com
# ...          ...              ...             ...                      ...
# 1440        1441  Jamaal Morrison       not_found  jamaal.morrison@msn.com
# 1441        1442     Cassie Cline       not_found   cassie.cline@gmail.com
# 1442        1443      Lezlie Lamb       not_found    lezlie.lamb@gmail.com
# 1443        1444     Ivette Estes       not_found   ivette.estes@gmail.com
# 1444        1445    Ester Acevedo       not_found  ester.acevedo@gmail.com
#
#                      Street           City State  ZipCode
# ...

# %%
orders
# Out:
#       OrderId  CustomerId  OrderStatus   OrderDate RequiredDate ShippedDate  \
# 0           1         259  4-Completed  2016-01-01   2016-01-03  2016-01-03
# 1           2        1212  4-Completed  2016-01-01   2016-01-04  2016-01-03
# 2           3         523  4-Completed  2016-01-02   2016-01-05  2016-01-03
# 3           4         175  4-Completed  2016-01-03   2016-01-04  2016-01-05
# 4           5        1324  4-Completed  2016-01-03   2016-01-06  2016-01-06
# ...       ...         ...          ...         ...          ...         ...
# 1610     1611           6   3-Rejected  2018-09-06   2018-09-06    NotFound
# 1611     1612           3   3-Rejected  2018-10-21   2018-10-21    NotFound
# 1612     1613           1   3-Rejected  2018-11-18   2018-11-18    NotFound
# 1613     1614         135   3-Rejected  2018-11-28   2018-11-28    NotFound
# 1614     1615         136   3-Rejected  2018-12-28   2018-12-28    NotFound
#
#       StoreId  StaffId
# 0           1        2
# ...

# %%
order_items
# Out:
#       OrderId  ItemId  ProductId  \
# 0           1       1         20
# 1           1       2          8
# 2           1       3         10
# 3           1       4         16
# 4           1       5          4
# ...       ...     ...        ...
# 4717     1614       2        159
# 4718     1614       3        213
# 4719     1615       1        197
# 4720     1615       2        214
# 4721     1615       3        182
#
#                                          ProductName  CategoryId  \
# 0     Electra Townie Original 7D EQ - Women's - 2016           3
# 1              Trek Remedy 29 Carbon Frameset - 2016           6
# 2                             Surly Straggler - 2016           4
# 3               Electra Townie Original 7D EQ - 2016           3
# 4                           Trek Fuel EX 8 29 - 2016           6
# ...                                              ...         ...
# 4717                        Trek Emonda ALR 6 - 2018           7
# ...

# %%
orders.describe()
# Out:
#            OrderId   CustomerId      StoreId      StaffId
# count  1615.000000  1615.000000  1615.000000  1615.000000
# mean    808.000000   654.171517     1.892260     5.855108
# std     466.354658   443.229967     0.558395     1.913899
# min       1.000000     1.000000     1.000000     2.000000
# 25%     404.500000   237.000000     2.000000     6.000000
# 50%     808.000000   638.000000     2.000000     6.000000
# 75%    1211.500000  1041.500000     2.000000     7.000000
# max    1615.000000  1445.000000     3.000000     9.000000

# %%
orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1615 entries, 0 to 1614
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderId       1615 non-null   int64
#  1   CustomerId    1615 non-null   int64
#  2   OrderStatus   1615 non-null   str
#  3   OrderDate     1615 non-null   object
#  4   RequiredDate  1615 non-null   object
#  5   ShippedDate   1615 non-null   str
#  6   StoreId       1615 non-null   int64
#  7   StaffId       1615 non-null   int64
# dtypes: int64(4), object(2), str(2)
# memory usage: 101.1+ KB

# %%
orders.value_counts()
# Out:
# OrderId  CustomerId  OrderStatus  OrderDate   RequiredDate  ShippedDate  StoreId  StaffId
# 1        259         4-Completed  2016-01-01  2016-01-03    2016-01-03   1        2          1
# 2        1212        4-Completed  2016-01-01  2016-01-04    2016-01-03   2        6          1
# 3        523         4-Completed  2016-01-02  2016-01-05    2016-01-03   2        7          1
# 4        175         4-Completed  2016-01-03  2016-01-04    2016-01-05   1        3          1
# 5        1324        4-Completed  2016-01-03  2016-01-06    2016-01-06   2        6          1
#                                                                                             ..
# 1611     6           3-Rejected   2018-09-06  2018-09-06    NotFound     2        7          1
# 1612     3           3-Rejected   2018-10-21  2018-10-21    NotFound     1        3          1
# 1613     1           3-Rejected   2018-11-18  2018-11-18    NotFound     2        6          1
# ...

# %%
customers.describe()
# Out:
#         CustomerId       ZipCode
# count  1445.000000   1445.000000
# mean    723.000000  34200.015225
# std     417.279882  34733.933551
# min       1.000000  10002.000000
# 25%     362.000000  11419.000000
# 50%     723.000000  11967.000000
# 75%    1084.000000  76110.000000
# max    1445.000000  95993.000000

# %%
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1445 entries, 0 to 1444
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerId  1445 non-null   int64
#  1   Name        1445 non-null   str
#  2   Phone       1445 non-null   str
#  3   Email       1445 non-null   str
#  4   Street      1445 non-null   str
#  5   City        1445 non-null   str
#  6   State       1445 non-null   str
#  7   ZipCode     1445 non-null   int64
# dtypes: int64(2), str(6)
# memory usage: 90.4 KB

# %%
customers.value_counts()
# Out:
# CustomerId  Name             Phone           Email                    Street                 City           State  ZipCode
# 1           Debra Burks      not_found       debra.burks@yahoo.com    9273 Thorne Ave.       Orchard Park   NY     14127      1
# 2           Kasha Todd       not_found       kasha.todd@yahoo.com     910 Vine Street        Campbell       CA     95008      1
# 3           Tameka Fisher    not_found       tameka.fisher@aol.com    769C Honey Creek St.   Redondo Beach  CA     90278      1
# 4           Daryl Spence     not_found       daryl.spence@aol.com     988 Pearl Lane         Uniondale      NY     11553      1
# 5           Charolette Rice  (916) 381-6003  charolette.rice@msn.com  107 River Dr.          Sacramento     CA     95820      1
#                                                                                                                              ..
# ...

# %%
describe = order_items.describe()
describe
# Out:
#            OrderId       ItemId    ProductId   CategoryId     Quantity  \
# count  4722.000000  4722.000000  4722.000000  4722.000000  4722.000000
# mean    821.265354     2.262601    59.366158     3.930961     1.498941
# std     465.152168     1.199129    67.312708     1.857648     0.500052
# min       1.000000     1.000000     2.000000     1.000000     1.000000
# 25%     423.250000     1.000000    14.000000     3.000000     1.000000
# 50%     828.500000     2.000000    28.000000     3.000000     1.000000
# 75%    1226.000000     3.000000    84.000000     6.000000     2.000000
# max    1615.000000     5.000000   315.000000     7.000000     2.000000
#
#           ListPrice     Discount    TotalSales
# count   4722.000000  4722.000000   4722.000000
# mean    1212.707872     0.105373   1628.360135
# std     1352.798257     0.058119   2017.917656
# min       89.990000     0.050000     71.992000
# 25%      429.000000     0.050000    474.981000
# ...

# %%
order_items.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4722 entries, 0 to 4721
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderId       4722 non-null   int64
#  1   ItemId        4722 non-null   int64
#  2   ProductId     4722 non-null   int64
#  3   ProductName   4722 non-null   str
#  4   CategoryId    4722 non-null   int64
#  5   CategoryName  4722 non-null   str
#  6   Quantity      4722 non-null   int64
#  7   ListPrice     4722 non-null   float64
#  8   Discount      4722 non-null   float64
#  9   TotalSales    4722 non-null   float64
#  10  OrderItems    4722 non-null   str
# dtypes: float64(3), int64(5), str(3)
# memory usage: 405.9 KB

# %%
order_items.value_counts()
# Out:
# OrderId  ItemId  ProductId  ProductName                                     CategoryId  CategoryName         Quantity  ListPrice  Discount  TotalSales  OrderItems
# 1        1       20         Electra Townie Original 7D EQ - Women's - 2016  3           Cruisers Bicycles    1         599.99     0.20      479.9920    HighPrice     1
#          2       8          Trek Remedy 29 Carbon Frameset - 2016           6           Mountain Bikes       2         1799.99    0.07      3347.9814   HighPrice     1
#          3       10         Surly Straggler - 2016                          4           Cyclocross Bicycles  2         1549.00    0.05      2943.1000   HighPrice     1
#          4       16         Electra Townie Original 7D EQ - 2016            3           Cruisers Bicycles    2         599.99     0.05      1139.9810   HighPrice     1
# ...

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
status_counts = orders["OrderStatus"].value_counts()

plt.bar(status_counts.index, status_counts.values)
plt.xlabel("Order Status")
plt.ylabel("Count")
plt.title("Orders by Status")
plt.show()

# %%
status_counts
# Out:
# OrderStatus
# 4-Completed     1445
# 2-Processing      63
# 1-Pending         62
# 3-Rejected        45
# Name: count, dtype: int64

# %%
customers
# Out:
#       CustomerId             Name           Phone                    Email  \
# 0              1      Debra Burks       not_found    debra.burks@yahoo.com
# 1              2       Kasha Todd       not_found     kasha.todd@yahoo.com
# 2              3    Tameka Fisher       not_found    tameka.fisher@aol.com
# 3              4     Daryl Spence       not_found     daryl.spence@aol.com
# 4              5  Charolette Rice  (916) 381-6003  charolette.rice@msn.com
# ...          ...              ...             ...                      ...
# 1440        1441  Jamaal Morrison       not_found  jamaal.morrison@msn.com
# 1441        1442     Cassie Cline       not_found   cassie.cline@gmail.com
# 1442        1443      Lezlie Lamb       not_found    lezlie.lamb@gmail.com
# 1443        1444     Ivette Estes       not_found   ivette.estes@gmail.com
# 1444        1445    Ester Acevedo       not_found  ester.acevedo@gmail.com
#
#                      Street           City State  ZipCode
# ...

# %%
cust_count = customers["State"].value_counts()

plt.bar(status_counts.index, status_counts.values)
# Out:
# <BarContainer object of 4 artists>

# %%
status_counts = customers["State"].value_counts()

plt.bar(status_counts.index, status_counts.values)
plt.xlabel("State")
plt.ylabel("Count")
plt.title("Total customers in each state")
plt.show()

# %%
status_counts = customers["State"].value_counts()

plt.scatter(status_counts.index, status_counts.values)
plt.xlabel("State")
plt.ylabel("Count")
plt.title("Total customers in each state")
plt.show()

# %%
status_counts = customers["State"].value_counts()

plt.plot(status_counts.index, status_counts.values)
plt.xlabel("State")
plt.ylabel("Count")
plt.title("Total customers in each state")
plt.show()

# %%
orders['OrderDate'] = pd.to_datetime(orders['OrderDate'])

# %%
reference_date = orders['OrderDate'].max() + pd.Timedelta(days=1)

# %%
reference_date = orders['OrderDate'].max() + pd.Timedelta(days=1)

# %%
rfm_df = pd.merge(orders, order_items, on='OrderId')
consumer_segments = rfm_df.groupby('CustomerId').agg({
    'OrderDate': lambda x: (reference_date - x.max()).days,
    'OrderId': 'nunique',
    'TotalSales': 'sum'
})

consumer_segments.columns = ['Recency', 'Frequency', 'Monetary']

print(rfm.head())
# Out:
#             Recency  Frequency    Monetary
# CustomerId
# 1                41          3  27888.1834
# 2               264          3  19329.0849
# 3                69          3  24051.5279
# 4               255          3  21150.8927
# 5               256          3  17520.2919

# %%
consumer_segments = consumer_segments.reset_index()
consumer_segments
# Out:
#       CustomerId  Recency  Frequency    Monetary
# 0              1       41          3  27888.1834
# 1              2      264          3  19329.0849
# 2              3       69          3  24051.5279
# 3              4      255          3  21150.8927
# 4              5      256          3  17520.2919
# ...          ...      ...        ...         ...
# 1440        1441      337          1   9173.3817
# 1441        1442      517          1   6987.2487
# 1442        1443      774          1  10372.0934
# 1443        1444      739          1   1399.9760
# 1444        1445      297          1   7999.9840
#
# [1445 rows x 4 columns]

# %%
# !pip install sqlalchemy pymysql

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+pymysql://root:your_password@localhost/hero")

# %%
engine = create_engine("mysql+pymysql://root:7539901997@localhost/hero")

# %%
consumer_segments.to_sql(
    name="consumer_segments",
    con=engine,
    if_exists="replace",
    index=False
)

print("Table imported successfully!")
# Out:
# Table imported successfully!
